# %%
def bird_dict(file):
    #opens the data file from Thomas et al and extracts the species and family as a dictionary
    bird_dict={}
    #open file
    ff=open(file, encoding = "ISO-8859-15")
    #read file
    ss = ff.readlines()[1:]
    #split lines on comma
    #stick species and family into bird dict
    for line in ss:
        sp = line.split(",")[0]
        fam = line.split(",")[2]
        bird_dict[sp] = fam
    ff.close()
    return bird_dict

# %%
bird_dict('/home/eeb177-student/Desktop/eeb234/eeb-177/homework/exercise-5/nature21074-s4.csv')
# Out:
# {'Eremalauda_starki': 'Alaudidae',
#  'Melocichla_mentalis': 'Sylviidae',
#  'Crinifer_piscator': 'Musophagidae',
#  'Neochelidon_tibialis': 'Hirundinidae',
#  'Pionites_melanocephalus': 'Psittacidae',
#  'Neochmia_temporalis': 'Estrildidae',
#  'Oreomystis_mana': 'Fringillidae',
#  'Anthocephala_floriceps': 'Trochilidae',
#  'Pygiptila_stellaris': 'Thamnophilidae',
#  'Ergaticus_ruber': 'Parulidae',
#  'Buphagus_erythrorhynchus': 'Sturnidae',
#  'Thamnophilus_doliatus': 'Thamnophilidae',
#  'Myornis_senilis': 'Rhinocryptidae',
#  'Riparia_cincta': 'Hirundinidae',
#  'Butastur_rufipennis': 'Accipitridae',
#  'Cardellina_rubrifrons': 'Parulidae',
#  'Ochthoeca_frontalis': 'Tyrannidae',
#  'Poliocephalus_poliocephalus': 'Podicipedidae',
#  'Paroaria_coronata': 'Emberizidae',
#  'Bradypterus_thoracicus': 'Sylviidae',
#  'Rhodinocichla_rosea': 'Thraupidae',
#  'Acanthisitta_chloris': 'Acanthisittidae',
#  'Atlantisia_rogersi': 'Rallidae',
#  'Acanthornis_magna': 'Acanthizidae',
# ...
